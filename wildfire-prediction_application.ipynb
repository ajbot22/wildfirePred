# %%
# Wildfire Detection DS420
### Authors: Aj Botticelli & Yusuke Satani
### Date: Spring 2023
### Goal: Using satellite image data from Kaggle (from the Canadian Govt), predict wildfire occurances in a model integrated with spark for real-time parsing
#Based from https://www.tensorflow.org/api_docs/python/tf/keras/preprocessing/image/ImageDataGenerator
#and https://vijayabhaskar96.medium.com/tutorial-image-classification-with-keras-flow-from-directory-and-generators-95f75ebe5720

# %% [markdown]
# ## Imports

# %%
import numpy as np

import matplotlib.pyplot as plt

import pandas as pd

import seaborn as sns
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import pathlib

# %% [markdown]
# ## Preproccessing

# %%
pathTrain = "../input/wildfire-prediction-dataset/train"
pathVal = "../input/wildfire-prediction-dataset/valid"
pathTest = "../input/wildfire-prediction-dataset/test"

# %%
trainDatagen = ImageDataGenerator()
testDatagen = ImageDataGenerator()
validationDatagen = ImageDataGenerator()

# %%
#Target size chosen arbitrarily along with batch size
trainGenerator = trainDatagen.flow_from_directory(
    pathTrain,
    target_size=(256, 256),
    batch_size=256, 
)
#from train dataset, nowildfire/wildfire
# Out:
# Found 30250 images belonging to 2 classes.

# %%
from collections import Counter

# %%
counter = Counter(trainGenerator.classes)
print(counter.items())
# Out:
# dict_items([(0, 14500), (1, 15750)])

# %%
plt

# %%
testGenerator = testDatagen.flow_from_directory(
    pathTest,
    target_size=(256, 256),
    batch_size=256, 
)
# Out:
# Found 6300 images belonging to 2 classes.

# %%
counter = Counter(testGenerator.classes)
print(counter.items())
# Out:
# dict_items([(0, 2820), (1, 3480)])

# %%
validGenerator = validationDatagen.flow_from_directory(
    pathVal,
    target_size=(256, 256),
    batch_size=256, 
)
# Out:
# Found 6300 images belonging to 2 classes.

# %%
counter = Counter(validGenerator.classes)
print(counter.items())
# Out:
# dict_items([(0, 2820), (1, 3480)])

# %%
## data visualization

# %%
fig=plt.figure(figsize=(15, 10))
columns = 4; rows = 5
for i,image in enumerate(items[0][:25], 1):
    img = cv2.imread(trainGenerator[i],(256,256))
    img = cv2.resize(img)
    fig.add_subplot(rows, columns, i)
    plt.imshow(img)
    plt.axis(False)

# %%
items = next(iter(trainGenerator))
#enumurate produces indexes also
plt.figure(figsize=(12,12))
for i, image in enumerate(items[0][:25], 1):
    plt.subplot(5,5,i)
    plt.imshow(image)
    plt.axis('off')

# %%
|
